# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install causalinference
# Out:
# Collecting causalinference
#   Downloading CausalInference-0.1.3-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.3 MB/s
# Installing collected packages: causalinference
# Successfully installed causalinference-0.1.3

# %%
# https://pypi.org/project/CausalInference/
from causalinference import CausalModel

# %%
lalonde = pd.read_csv('/ihdp.csv', index_col=0)
lalonde.head()
# Out:
#                 x2        x3        x4  ...        yf       ycf       ite
# x1                                      ...
# 1.397395  0.996346 -1.105624 -0.879606  ...  4.771232 -0.298509  4.657928
# 0.269033  0.196818  0.383828  0.161703  ...  2.956273  5.783770  3.428604
# 1.051537  1.795874 -1.105624  0.161703  ...  4.164164  7.055789  3.658195
# 0.662446  0.196818 -0.733261 -0.879606  ...  6.172307  1.379697  4.585505
# 0.856992  1.795874  0.011465 -0.879606  ...  7.834469  2.747986  4.265591
#
# [5 rows x 28 columns]

# %%
# let's have an overview of the data
lalonde.describe()
# Out:
#                  x2            x3  ...         ycf         ite
# count  7.470000e+02  7.470000e+02  ...  747.000000  747.000000
# mean   2.348263e-17 -4.666801e-17  ...    5.696107    4.016067
# std    1.000000e+00  1.000000e+00  ...    1.980121    0.859736
# min   -3.800823e+00 -1.850350e+00  ...   -1.037628   -1.866989
# 25%   -6.027100e-01 -7.332610e-01  ...    5.053598    3.775936
# 50%    1.968181e-01 -3.608980e-01  ...    6.209686    4.304433
# 75%    5.965822e-01  7.561910e-01  ...    6.948922    4.569454
# max    2.595403e+00  2.990369e+00  ...   10.171004    4.670125
#
# [8 rows x 28 columns]
